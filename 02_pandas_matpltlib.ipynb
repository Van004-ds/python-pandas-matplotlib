# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#2d vector 
v_2d = np.array([1,2,3,4,4,5])
print("2d vector :" , v_2d)
print(type(v_2d))
v1 = np.array([1,2,3,4])
print(v_2d.shape)
print(v1.ndim)
print(v_2d.ndim)
# Out:
# 2d vector : [1 2 3 4 4 5]
# <class 'numpy.ndarray'>
# (6,)
# 1
# 1

# %%
#vector addition

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
v = np.array([1,2,3])
ax.scatter(v[0] ,v[1],v[2], color ='r',label ='vector point')
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.legend()
plt.show()

# %%
#scalr multiplication with vector

# %%
k = -2
v= np.array([1,2,3])
scaler_vector = k * v
print(scaler_vector)
# Out:
# [-2 -4 -6]

# %%
#wap in p ython that accepts the list of funtion

# %%
def function_list(numberlist):
    even_num = []
    for i in numberlist :
        if i % 2 == 0 :
            even_num.append(i)


    return sum(even_num)


a = [1,2,3,4,5]
new_list = function_list(a)
print(new_list)
# Out:
# 6

# %%
 def ar(list1):
    new_list_array = np.array(list1)

    return new_list_array

list1 = []
for i in range (1,9):
    value  = int(input("enter list values "))
    list1.append(value )



print(ar(list1))
# Out:
# enter list values  980
# enter list values  8
# enter list values  0989
# enter list values  00
# enter list values  0
# enter list values  9
# enter list values  9
# enter list values  997
# [980   8 989   0   0   9   9 997]

# %% [markdown]
# #  pandas ( data manipulation )

# %%
 def pan_da(list3):
    df = pd.DataFrame(list3)
    return df
    
    
    


    


data = [{"name": "hello", "Age":34,"salary" :"1 million euros"},{"name": "henna", "Age":45,"salary" :"10 million euros"},
        {"name": "alicee", "Age":44,"salary" :"2 million euros"},
{"name": "bob", "Age":54,"salary" :"9 million euros"},
{"name": "charlie", "Age":51,"salary" :"90 million euros"}
       ]
   
df = pan_da(data)
print(df)
print("/n")



print(df.iloc[:,[0,2]])
# Out:
#       name  Age            salary
# 0    hello   34   1 million euros
# 1    henna   45  10 million euros
# 2   alicee   44   2 million euros
# 3      bob   54   9 million euros
# 4  charlie   51  90 million euros
# /n
#       name            salary
# 0    hello   1 million euros
# 1    henna  10 million euros
# 2   alicee   2 million euros
# 3      bob   9 million euros
# 4  charlie  90 million euros

# %% [markdown]
# # reading and writing data
